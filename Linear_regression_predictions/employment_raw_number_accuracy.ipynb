# %%
import pymongo
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from pymongo import MongoClient

# %%
# Connection URI
client = MongoClient('mongodb+srv://project_user:qsdapUweFvhdbouy@cluster0.l3pqt.mongodb.net/MSA?retryWrites=true&w=majority')
# Select database
db = client['MSA']
# Select the collection within the database (in this case its GDP_raw data, check list below for other collections)
employment = db.employment_raw
# Convert entire collection to Pandas dataframe
df = pd.DataFrame(list(employment.find()))
df
# Out:
#                           _id       2001       2002       2003       2004  \
# 0    602cbb2ed9e65148e4b7ce1b  142876022  142590402  143452007  146128722
# 1    602cbb2ed9e65148e4b7ce1c      89511      90338      91132      91998
# 2    602cbb2ed9e65148e4b7ce1d     396954     396663     396391     404591
# 3    602cbb2ed9e65148e4b7ce1e      78011      77100      78282      78126
# 4    602cbb2ed9e65148e4b7ce1f      54749      54136      53710      54697
# ..                        ...        ...        ...        ...        ...
# 380  602cbb2ed9e65148e4b7cf97     112685     112734     114189     113223
# 381  602cbb2ed9e65148e4b7cf98     211514     211138     211658     217006
# 382  602cbb2ed9e65148e4b7cf99     311150     305452     302591     301803
# 383  602cbb2ed9e65148e4b7cf9a      61499      62404      62573      63898
# 384  602cbb2ed9e65148e4b7cf9b      70656      72784      74549      78518
#
#           2005       2006       2007       2008       2009  ...       2012  \
# ...

# %%
# drop _id column
df.drop(columns ='_id', inplace=True)

# rearrange columns
df = df[['GeoFips', 'GeoName', '2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015', '2016', '2017', '2018', '2019']]

df
# Out:
#     GeoFips                                            GeoName       2001  \
# 0       998               United States (Metropolitan Portion)  142876022
# 1     10180        Abilene, TX (Metropolitan Statistical Area)      89511
# 2     10420          Akron, OH (Metropolitan Statistical Area)     396954
# 3     10500         Albany, GA (Metropolitan Statistical Area)      78011
# 4     10540  Albany-Lebanon, OR (Metropolitan Statistical A...      54749
# ..      ...                                                ...        ...
# 380   49420         Yakima, WA (Metropolitan Statistical Area)     112685
# 381   49620   York-Hanover, PA (Metropolitan Statistical Area)     211514
# 382   49660  Youngstown-Warren-Boardman, OH-PA (Metropolita...     311150
# 383   49700      Yuba City, CA (Metropolitan Statistical Area)      61499
# 384   49740           Yuma, AZ (Metropolitan Statistical Area)      70656
#
#           2002       2003       2004       2005       2006       2007  \
# ...

# %%
df.dtypes
# Out:
# GeoFips    object
# GeoName    object
# 2001       object
# 2002       object
# 2003       object
# 2004       object
# 2005       object
# 2006       object
# 2007       object
# 2008       object
# 2009       object
# 2010       object
# 2011       object
# 2012       object
# 2013       object
# 2014       object
# 2015       object
# 2016       object
# 2017       object
# 2018       object
# 2019       object
# dtype: object

# %%
# change values in years columns to float
df[['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015', '2016', '2017', '2018', '2019']]= df[['2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']].apply(pd.to_numeric)
df.dtypes
# Out:
# GeoFips    object
# GeoName    object
# 2001        int64
# 2002        int64
# 2003        int64
# 2004        int64
# 2005        int64
# 2006        int64
# 2007        int64
# 2008        int64
# 2009        int64
# 2010        int64
# 2011        int64
# 2012        int64
# 2013        int64
# 2014        int64
# 2015        int64
# 2016        int64
# 2017        int64
# 2018        int64
# 2019        int64
# dtype: object

# %%
# instantiate linearRegression
model = LinearRegression()

# %%
predictions = []
for i in range(0,385):
    x = [[2001],[2002],[2003],[2004],[2005],[2006],[2007],[2008],[2009],[2010],[2011],[2012],[2013],[2014],[2015],[2016],[2017],[2018]]
    y = df.iloc[i, 2:20].values
    model.fit(x,y)
    y_pred = model.predict([[2019]])
    predictions.append(y_pred)
flat_list = [item for sublist in predictions for item in sublist]
df['prediction_2019'] = flat_list
df
# Out:
#     GeoFips                                            GeoName       2001  \
# 0       998               United States (Metropolitan Portion)  142876022
# 1     10180        Abilene, TX (Metropolitan Statistical Area)      89511
# 2     10420          Akron, OH (Metropolitan Statistical Area)     396954
# 3     10500         Albany, GA (Metropolitan Statistical Area)      78011
# 4     10540  Albany-Lebanon, OR (Metropolitan Statistical A...      54749
# ..      ...                                                ...        ...
# 380   49420         Yakima, WA (Metropolitan Statistical Area)     112685
# 381   49620   York-Hanover, PA (Metropolitan Statistical Area)     211514
# 382   49660  Youngstown-Warren-Boardman, OH-PA (Metropolita...     311150
# 383   49700      Yuba City, CA (Metropolitan Statistical Area)      61499
# 384   49740           Yuma, AZ (Metropolitan Statistical Area)      70656
#
#           2002       2003       2004       2005       2006       2007  \
# ...

# %%
# create new dataframe to hold actual 2019 and predicted 2019 values
df_accuracy = df[['2019']].copy()
df_accuracy['Predicted_2019'] = flat_list
df_accuracy
# Out:
#           2019  Predicted_2019
# 0    179929128    1.732211e+08
# 1       107405    1.058248e+05
# 2       433800    4.296488e+05
# 3        83286    8.189269e+04
# 4        64277    6.071922e+04
# ..         ...             ...
# 380     136556    1.339093e+05
# 381     243152    2.391924e+05
# 382     283700    2.790680e+05
# 383      75581    7.024058e+04
# 384      91296    8.986479e+04
#
# [385 rows x 2 columns]

# %%
# calculate percent error for each linear regression
df_accuracy['Percent_Error'] = (df_accuracy['2019'] - df_accuracy['Predicted_2019'])/df_accuracy['2019']*100

# set values to absolute in percent_error column
df_accuracy['Percent_Error'] = df_accuracy['Percent_Error'].abs()

# print mean of a percent_error
mean_percent_error = df_accuracy['Percent_Error'].mean()
print(f'Average percent error for linear regression predicting 2019 raw employment numbers is: {round(mean_percent_error,3)}%' )
df_accuracy
# Out:
# Average percent error for linear regression predicting 2019 raw employment numbers is: 3.198%
#           2019  Predicted_2019  Percent_Error
# 0    179929128    1.732211e+08       3.728137
# 1       107405    1.058248e+05       1.471207
# 2       433800    4.296488e+05       0.956947
# 3        83286    8.189269e+04       1.672919
# 4        64277    6.071922e+04       5.535071
# ..         ...             ...            ...
# 380     136556    1.339093e+05       1.938179
# 381     243152    2.391924e+05       1.628436
# 382     283700    2.790680e+05       1.632699
# 383      75581    7.024058e+04       7.065821
# 384      91296    8.986479e+04       1.567658
#
# [385 rows x 3 columns]

# %%
# create dataframe to store back into mongo with predictions and rank
employment_clean = df[['GeoFips', 'GeoName', 'prediction_2024']].copy()

employment_clean['Rank'] = df['prediction_2024'].rank()

employment_clean
# Out:
#     GeoFips                                            GeoName  \
# 0       998               United States (Metropolitan Portion)
# 1     10180        Abilene, TX (Metropolitan Statistical Area)
# 2     10420          Akron, OH (Metropolitan Statistical Area)
# 3     10500         Albany, GA (Metropolitan Statistical Area)
# 4     10540  Albany-Lebanon, OR (Metropolitan Statistical A...
# ..      ...                                                ...
# 380   49420         Yakima, WA (Metropolitan Statistical Area)
# 381   49620   York-Hanover, PA (Metropolitan Statistical Area)
# 382   49660  Youngstown-Warren-Boardman, OH-PA (Metropolita...
# 383   49700      Yuba City, CA (Metropolitan Statistical Area)
# 384   49740           Yuma, AZ (Metropolitan Statistical Area)
#
#      prediction_2024   Rank
# 0       1.841420e+08  385.0
# 1       1.106703e+05  150.0
# 2       4.391737e+05  303.0
# 3       8.336014e+04  103.0
# 4       6.347644e+04   49.0
# ..               ...    ...
# ...

# %%
employment_clean.drop([0],inplace =True)
employment_clean
# Out:
#     GeoFips                                            GeoName  \
# 1     10180        Abilene, TX (Metropolitan Statistical Area)
# 2     10420          Akron, OH (Metropolitan Statistical Area)
# 3     10500         Albany, GA (Metropolitan Statistical Area)
# 4     10540  Albany-Lebanon, OR (Metropolitan Statistical A...
# 5     10580  Albany-Schenectady-Troy, NY (Metropolitan Stat...
# ..      ...                                                ...
# 380   49420         Yakima, WA (Metropolitan Statistical Area)
# 381   49620   York-Hanover, PA (Metropolitan Statistical Area)
# 382   49660  Youngstown-Warren-Boardman, OH-PA (Metropolita...
# 383   49700      Yuba City, CA (Metropolitan Statistical Area)
# 384   49740           Yuma, AZ (Metropolitan Statistical Area)
#
#      prediction_2024   Rank
# 1      110670.273684  150.0
# 2      439173.715789  303.0
# 3       83360.143860  103.0
# 4       63476.438596   49.0
# 5      586495.389474  328.0
# ..               ...    ...
# ...

# %%
# export unemployment clean dataframe back to mongo
