# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv('features_for_fit.csv')
df
# Out:
#       CBSA                                MSA  Employment        GDP  \
# 0    10180                        abilene, tx    4.672014  16.444673
# 1    10420                          akron, oh    1.819752  11.310636
# 2    10500                         albany, ga    2.294333  16.066871
# 3    10540                 albany-lebanon, or    8.949608  25.114448
# 4    10580        albany-schenectady-troy, ny    4.109291  18.285130
# ..     ...                                ...         ...        ...
# 378  49420                         yakima, wa    6.186625  24.300861
# 379  49620                   york-hanover, pa    4.926748  12.935877
# 380  49660  youngstown-warren-boardman, oh-pa   -1.471502   8.218357
# 381  49700                      yuba city, ca   10.104159  24.611951
# 382  49740                           yuma, az    6.405594  23.802286
#
#      Population  Unemployment   Total
# 0      1.397860           3.0   670.5
# 1     -0.128197           4.3  1139.5
# 2     -2.434386           4.3  1101.5
# 3      7.911940           4.3   446.5
# 4      0.147426           3.7   825.5
# ..          ...           ...     ...
# 378    1.240113           7.0   815.0
# 379    1.656400           3.8   856.0
# 380   -2.317246           5.7  1414.5
# 381    3.727698           6.8   614.0
# 382    4.191806          16.4   698.0
#
# [383 rows x 7 columns]

# %%
# Target "Emerging" and "Static" based off of top 40 MSA's with best ranking score.
df.loc[df['Total'] < 300, 'Target'] = 'Emerging'
df.loc[df['Total'] >300, 'Target'] = 'Static'

# %%
# set x and y data
y = df['Target']
X = df.drop(columns=['CBSA','MSA', 'Total', 'Target'])

# %%
# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
Counter(y_train)
# Out:
# Counter({'Static': 254, 'Emerging': 33})

# %%
# instantiate the model a fit using the training sets
model = LogisticRegression(solver='lbfgs', max_iter=50, random_state=42, class_weight={'Emerging':0.5})
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight={'Emerging': 0.5}, max_iter=50, random_state=42)

# %%
# test the model accuracy
y_pred = model.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 1.0
# [[ 7  0]
#  [ 0 89]]
#               precision    recall  f1-score   support
#
#     Emerging       1.00      1.00      1.00         7
#       Static       1.00      1.00      1.00        89
#
#     accuracy                           1.00        96
#    macro avg       1.00      1.00      1.00        96
# weighted avg       1.00      1.00      1.00        96

# %%
# import feature set to run predictions on 2024 data
df_2024 = pd.read_csv('2024_ROC_rank_total.csv')
df_2024.head()
# Out:
#     CBSA            Metropolitan_Area  2024_Pop_ROC  2024_Unem_ROC  \
# 0  10180                  Abilene, TX           2.0           1.15
# 1  10500                   Albany, GA          -3.2           2.58
# 2  10420                    Akron, OH           0.2           1.20
# 3  10540           Albany-Lebanon, OR           3.9           2.05
# 4  10580  Albany-Schenectady-Troy, NY           1.0           1.17
#
#    2024_Emp_ROC  2024_GDP_ROC  Pop_ROC_Rank  Unem_ROC_Rank  Emp_ROC_Rank  \
# 0      3.040151      8.072256         217.5           38.0         134.0
# 1      0.089023      7.199080         370.0          349.0         260.0
# 2      1.238754     12.475028         286.5           76.5         214.0
# 3     -1.245487     17.059092         142.0          304.5         312.0
# 4      1.270928     14.602271         257.5           53.0         211.0
#
#    GDP_ROC_Rank  Rank_Total
# 0         297.0       686.5
# 1         312.0      1291.0
# 2         201.0       778.0
# 3          88.0       846.5
# 4         155.0       676.5

# %%
df_2024.columns.tolist()
# Out:
# ['CBSA',
#  'Metropolitan_Area',
#  '2024_Pop_ROC',
#  '2024_Unem_ROC',
#  '2024_Emp_ROC',
#  '2024_GDP_ROC',
#  'Pop_ROC_Rank',
#  'Unem_ROC_Rank',
#  'Emp_ROC_Rank',
#  'GDP_ROC_Rank',
#  'Rank_Total']

# %%
# set x2 data for logisticRegression prediction
X2 = df_2024.drop(columns=['CBSA',
 'Metropolitan_Area',
 'Pop_ROC_Rank',
 'Unem_ROC_Rank',
 'Emp_ROC_Rank',
 'GDP_ROC_Rank',
 'Rank_Total'])
X2.head()
# Out:
#    2024_Pop_ROC  2024_Unem_ROC  2024_Emp_ROC  2024_GDP_ROC
# 0           2.0           1.15      3.040151      8.072256
# 1          -3.2           2.58      0.089023      7.199080
# 2           0.2           1.20      1.238754     12.475028
# 3           3.9           2.05     -1.245487     17.059092
# 4           1.0           1.17      1.270928     14.602271

# %%
# reorder columns to match training data columns
X2 = X2[['2024_Emp_ROC','2024_GDP_ROC','2024_Pop_ROC','2024_Unem_ROC']]
X2.head()
# Out:
#    2024_Emp_ROC  2024_GDP_ROC  2024_Pop_ROC  2024_Unem_ROC
# 0      3.040151      8.072256           2.0           1.15
# 1      0.089023      7.199080          -3.2           2.58
# 2      1.238754     12.475028           0.2           1.20
# 3     -1.245487     17.059092           3.9           2.05
# 4      1.270928     14.602271           1.0           1.17

# %%
# run the logisticRegression model over our 2024 data set
emerging_pred = model.predict(X2)
# added predicted classifiers back into original dataframe
df_2024['Predicted_Classifier_LR'] = emerging_pred
# dispay MSA that our ML model predicted to be emerging in 2024
df_2024.loc[df_2024['Predicted_Classifier_LR']=='Emerging']
# Out:
#       CBSA                               Metropolitan_Area  2024_Pop_ROC  \
# 11   11180                                        Ames, IA           4.9
# 17   12220                              Auburn-Opelika, AL           9.3
# 22   12420                Austin-Round Rock-Georgetown, TX          12.4
# 31   13460                                        Bend, OR          10.5
# 36   13900                                    Bismarck, ND          10.5
# 52   15980                       Cape Coral-Fort Myers, FL          11.5
# 58   16220                                      Casper, WY           4.1
# 63   16700                 Charleston-North Charleston, SC           9.8
# 65   16740               Charlotte-Concord-Gastonia, NC-SC           8.2
# 74   17660                               Coeur d'Alene, ID           7.5
# 75   17780                       College Station-Bryan, TX           8.6
# 80   18020                                    Columbus, IN           4.7
# 84   18880          Crestview-Fort Walton Beach-Destin, FL           8.7
# 86   19100                 Dallas-Fort Worth-Arlington, TX           9.0
# 89   19300                       Daphne-Fairhope-Foley, AL           9.3
# 95   19740                      Denver-Aurora-Lakewood, CO           8.5
# 96   19780                  Des Moines-West Des Moines, IA           7.6
# 100  20220                                     Dubuque, IA           2.3
# 107  21140                              Elkhart-Goshen, IN           2.6
# 115  22020                                    Fargo, ND-MN           9.9
# 118  22220              Fayetteville-Springdale-Rogers, AR           9.7
# 124  22660                                Fort Collins, CO           9.2
# 130  23580                                 Gainesville, GA           6.7
# 140  24540                                     Greeley, CO          11.3
# 159  26420            Houston-The Woodlands-Sugar Land, TX          10.3
# 164  26980                                   Iowa City, IA           8.0
# 195  29700                                      Laredo, TX           5.9
# 207  30860                                    Logan, UT-ID           5.6
# 228  33260                                     Midland, TX          12.3
# 237  34060                                  Morgantown, WV           4.9
# 246  34980  Nashville-Davidson--Murfreesboro--Franklin, TN           8.5
# 257  36420                               Oklahoma City, OK           6.5
# 260  36740                   Orlando-Kissimmee-Sanford, FL          10.9
# 265  37460                                 Panama City, FL          10.2
# 279  39340                                  Provo-Orem, UT           9.4
# 283  39580                                Raleigh-Cary, NC          10.1
# 300  41100                                  St. George, UT          10.5
# 308  41700                   San Antonio-New Braunfels, TX           9.1
# 309  41860              San Francisco-Oakland-Berkeley, CA           6.1
# 311  41940              San Jose-Sunnyvale-Santa Clara, CA           6.0
# 319  42660                     Seattle-Tacoma-Bellevue, WA           8.0
# 327  43620                                 Sioux Falls, SD           8.3
# 335  44300                               State College, PA           4.1
# 344  45540                                The Villages, FL          17.5
# 352  46340                                       Tyler, TX           5.2
#
#      2024_Unem_ROC  2024_Emp_ROC  2024_GDP_ROC  Pop_ROC_Rank  Unem_ROC_Rank  \
# 11            0.82      3.520560     18.096775         104.5            1.0
# 17            1.27      7.461697     20.463152          20.5          114.5
# 22            1.41      7.740261     23.695131           2.0          185.5
# 31            1.61      3.452002     30.132628           9.0          244.5
# 36            1.34     13.609255     22.560386           9.0          160.0
# 52            1.27      4.772877     20.047516           5.0          114.5
# 58            1.14     10.334702     14.395404         134.0           34.5
# 63            1.27      5.161834     20.541050          15.0          114.5
# 65            1.47      4.662991     20.556409          35.0          203.0
# 74            1.20      3.779303     17.598315          42.5           76.5
# 75            1.32      6.539422     12.853315          28.5          149.5
# 80            1.17      6.176093     13.576996         114.0           53.0
# 84            1.02      2.612557     15.209084          27.0            5.5
# 86            1.18      6.017757     19.622137          25.5           59.0
# 89            1.52      6.768682     17.724397          20.5          226.0
# 95            1.21      3.634379     19.081684          30.5           85.5
# 96            1.17      4.896860     24.355305          40.5           53.0
# 100           1.21      6.434534     18.802780         204.5           85.5
# 107           1.09     -1.242023     35.627427         194.5           14.5
# 115           1.05      9.286568     20.468566          14.0           10.0
# 118           1.25      5.977000     23.579081          16.0          108.0
# 124           1.33      4.110821     22.249300          22.5          157.5
# 130           1.16      4.813661     22.787754          53.0           44.0
# 140           1.25      5.772005     27.541953           6.0          108.0
# 159           1.27      8.585974     16.186088          11.0          114.5
# 164           1.44      7.969279     17.846792          37.5          195.0
# 195           1.21     11.238739     18.670049          70.5           85.5
# 207           1.40      6.251697     15.885937          75.0          176.5
# 228           1.32     13.470572     17.938530           3.5          149.5
# 237           1.12     10.129259     15.591279         104.5           19.0
# 246           1.19      2.487185     23.139641          30.5           63.0
# 257           1.20      5.964329     13.247027          55.0           76.5
# 260           1.38      3.383426     19.754767           7.0          171.0
# 265           1.52      8.331165     12.498735          12.0          226.0
# 279           1.37      6.339737     21.232358          19.0          166.5
# 283           1.31      7.020570     24.100152          13.0          145.0
# 300           1.20      6.722918     27.326079           9.0           76.5
# 308           1.12      7.222217     20.501309          24.0           22.5
# 309           1.19      1.557396     25.733088          65.5           63.0
# 311           1.09      0.733280     26.740720          68.5           13.0
# 319           1.21      2.608840     20.579317          37.5           85.5
# 327           1.31      6.735209     19.859865          34.0          146.0
# 335           1.14      7.441246     15.787866         134.0           28.5
# 344           2.64     18.714580     18.666587           1.0          351.0
# 352           1.14      8.514674      8.461186          88.0           28.5
#
#      Emp_ROC_Rank  GDP_ROC_Rank  Rank_Total Predicted_Classifier_LR  \
# 11          110.0          68.0       283.5                Emerging
# 17           30.0          30.0       195.0                Emerging
# 22           27.0          13.0       227.5                Emerging
# 31          117.0           4.0       374.5                Emerging
# 36            2.0          18.0       189.0                Emerging
# 52           75.0          33.0       227.5                Emerging
# 58            9.0         158.0       335.5                Emerging
# 63           67.0          26.0       222.5                Emerging
# 65           76.0          25.0       339.0                Emerging
# 74          102.0          80.0       301.0                Emerging
# 75           41.0         193.0       412.0                Emerging
# 80           50.0         178.0       395.0                Emerging
# 84          157.0         140.0       329.5                Emerging
# 86           53.0          38.0       175.5                Emerging
# 89           37.0          77.0       360.5                Emerging
# 95          106.0          46.0       268.0                Emerging
# 96           72.0           9.0       174.5                Emerging
# 100          45.0          50.0       385.0                Emerging
# 107         311.0           3.0       523.0                Emerging
# 115          14.0          29.0        67.0                Emerging
# 118          54.0          14.0       192.0                Emerging
# 124          89.0          19.0       288.0                Emerging
# 130          74.0          16.0       187.0                Emerging
# 140          57.0           5.0       176.0                Emerging
# 159          18.0         111.0       254.5                Emerging
# 164          25.0          75.0       332.5                Emerging
# 195           5.0          51.0       212.0                Emerging
# 207          49.0         115.0       415.5                Emerging
# 228           3.0          72.0       228.0                Emerging
# 237          11.0         126.0       260.5                Emerging
# 246         163.0          15.0       271.5                Emerging
# 257          56.0         186.0       373.5                Emerging
# 260         119.0          35.0       332.0                Emerging
# 265          21.0         200.0       459.0                Emerging
# 279          47.0          21.0       253.5                Emerging
# 283          36.0          12.0       206.0                Emerging
# 300          39.0           6.0       130.5                Emerging
# 308          34.0          28.0       108.5                Emerging
# 309         198.0           8.0       334.5                Emerging
# 311         240.0           7.0       328.5                Emerging
# 319         158.0          24.0       305.0                Emerging
# 327          38.0          34.0       252.0                Emerging
# 335          32.0         118.0       312.5                Emerging
# 344           1.0          52.0       405.0                Emerging
# 352          19.0         296.0       431.5                Emerging
#
#     Predicted_Classifier_svm Predicted_Classifier_RFC Predicted_Classifier_GBC
# 11                  Emerging                   Static                   Static
# 17                  Emerging                   Static                   Static
# 22                  Emerging                 Emerging                 Emerging
# 31                  Emerging                 Emerging                 Emerging
# 36                  Emerging                 Emerging                 Emerging
# 52                  Emerging                   Static                   Static
# 58                  Emerging                   Static                   Static
# 63                  Emerging                   Static                   Static
# 65                  Emerging                   Static                   Static
# 74                  Emerging                   Static                   Static
# 75                  Emerging                   Static                   Static
# 80                  Emerging                   Static                   Static
# 84                  Emerging                   Static                   Static
# 86                  Emerging                   Static                   Static
# 89                  Emerging                   Static                   Static
# 95                  Emerging                   Static                   Static
# 96                  Emerging                 Emerging                 Emerging
# 100                 Emerging                   Static                   Static
# 107                 Emerging                   Static                   Static
# 115                 Emerging                 Emerging                 Emerging
# 118                 Emerging                 Emerging                 Emerging
# 124                 Emerging                 Emerging                 Emerging
# 130                 Emerging                   Static                   Static
# 140                 Emerging                 Emerging                 Emerging
# 159                 Emerging                   Static                   Static
# 164                 Emerging                   Static                   Static
# 195                 Emerging                 Emerging                 Emerging
# 207                 Emerging                   Static                   Static
# 228                 Emerging                 Emerging                 Emerging
# 237                 Emerging                   Static                   Static
# 246                 Emerging                 Emerging                 Emerging
# 257                 Emerging                   Static                   Static
# 260                 Emerging                   Static                   Static
# 265                 Emerging                   Static                   Static
# 279                 Emerging                   Static                   Static
# 283                 Emerging                 Emerging                 Emerging
# 300                 Emerging                 Emerging                 Emerging
# 308                 Emerging                   Static                   Static
# 309                 Emerging                   Static                   Static
# 311                 Emerging                   Static                   Static
# 319                 Emerging                   Static                   Static
# 327                 Emerging                   Static                   Static
# 335                 Emerging                   Static                   Static
# 344                 Emerging                 Emerging                 Emerging
# 352                 Emerging                   Static                   Static

# %%
# use svm to predict emerging
# create SVM classifier
model_svm = SVC(kernel='linear')
model_svm.fit(X_train, y_train)
emerging_pred_svm = model_svm.predict(X2)
df_2024['Predicted_Classifier_svm'] = emerging_pred_svm
df_2024.loc[df_2024['Predicted_Classifier_svm']=='Emerging']
# Out:
#       CBSA                             Metropolitan_Area  2024_Pop_ROC  \
# 9    11100                                  Amarillo, TX           3.0
# 10   11260                                 Anchorage, AK           3.3
# 11   11180                                      Ames, IA           4.9
# 12   11460                                 Ann Arbor, MI           5.0
# 13   11540                                  Appleton, WI           3.0
# ..     ...                                           ...           ...
# 364  47900  Washington-Arlington-Alexandria, DC-VA-MD-WV           6.1
# 370  48300                                 Wenatchee, WA           4.3
# 371  48620                                   Wichita, KS           1.6
# 374  48900                                Wilmington, NC           8.4
# 375  49020                             Winchester, VA-WV           4.6
#
#      2024_Unem_ROC  2024_Emp_ROC  2024_GDP_ROC  Pop_ROC_Rank  Unem_ROC_Rank  \
# 9             1.40      6.122966     11.424719         180.0          176.5
# 10            1.40      7.444749      8.052706         167.5          175.0
# 11            0.82      3.520560     18.096775         104.5            1.0
# 12            1.15     -1.959702     17.030465          97.5           38.0
# 13            1.00      1.509336     17.355080         180.0            2.5
# ..             ...           ...           ...           ...            ...
# 364           1.29      4.069063     12.284865          65.5          129.0
# 370           1.78      5.227460     17.476622         129.5          273.0
# 371           1.18      0.698957     18.222154         239.0           60.0
# 374           1.52      3.746677     14.671400          32.5          226.0
# 375           1.19      3.364098     12.353159         120.0           63.0
#
#      Emp_ROC_Rank  GDP_ROC_Rank  Rank_Total Predicted_Classifier_LR  \
# 9            51.0         239.0       646.5                  Static
# 10           31.0         299.0       672.5                  Static
# 11          110.0          68.0       283.5                Emerging
# 12          331.0          89.0       555.5                  Static
# 13          201.0          85.0       468.5                  Static
# ..            ...           ...         ...                     ...
# 364          91.0         207.0       492.5                Emerging
# 370          66.0          82.0       550.5                  Static
# 371         242.0          63.0       604.0                  Static
# 374         104.0         153.0       515.5                Emerging
# 375         120.0         206.0       509.0                  Static
#
#     Predicted_Classifier_svm
# 9                   Emerging
# 10                  Emerging
# 11                  Emerging
# 12                  Emerging
# 13                  Emerging
# ..                       ...
# 364                 Emerging
# 370                 Emerging
# 371                 Emerging
# 374                 Emerging
# 375                 Emerging
#
# [151 rows x 13 columns]

# %%
# Creating a random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=42, class_weight={'Emerging':1.75})
rf_model.fit(X_train, y_train)
forest_predict = rf_model.predict(X2)
df_2024['Predicted_Classifier_RFC'] = forest_predict
df_2024.loc[df_2024['Predicted_Classifier_RFC']=='Emerging']
# Out:
#       CBSA                               Metropolitan_Area  2024_Pop_ROC  \
# 22   12420                Austin-Round Rock-Georgetown, TX          12.4
# 31   13460                                        Bend, OR          10.5
# 36   13900                                    Bismarck, ND          10.5
# 96   19780                  Des Moines-West Des Moines, IA           7.6
# 115  22020                                    Fargo, ND-MN           9.9
# 118  22220              Fayetteville-Springdale-Rogers, AR           9.7
# 124  22660                                Fort Collins, CO           9.2
# 140  24540                                     Greeley, CO          11.3
# 195  29700                                      Laredo, TX           5.9
# 228  33260                                     Midland, TX          12.3
# 246  34980  Nashville-Davidson--Murfreesboro--Franklin, TN           8.5
# 283  39580                                Raleigh-Cary, NC          10.1
# 300  41100                                  St. George, UT          10.5
# 344  45540                                The Villages, FL          17.5
#
#      2024_Unem_ROC  2024_Emp_ROC  2024_GDP_ROC  Pop_ROC_Rank  Unem_ROC_Rank  \
# 22            1.41      7.740261     23.695131           2.0          185.5
# 31            1.61      3.452002     30.132628           9.0          244.5
# 36            1.34     13.609255     22.560386           9.0          160.0
# 96            1.17      4.896860     24.355305          40.5           53.0
# 115           1.05      9.286568     20.468566          14.0           10.0
# 118           1.25      5.977000     23.579081          16.0          108.0
# 124           1.33      4.110821     22.249300          22.5          157.5
# 140           1.25      5.772005     27.541953           6.0          108.0
# 195           1.21     11.238739     18.670049          70.5           85.5
# 228           1.32     13.470572     17.938530           3.5          149.5
# 246           1.19      2.487185     23.139641          30.5           63.0
# 283           1.31      7.020570     24.100152          13.0          145.0
# 300           1.20      6.722918     27.326079           9.0           76.5
# 344           2.64     18.714580     18.666587           1.0          351.0
#
#      Emp_ROC_Rank  GDP_ROC_Rank  Rank_Total Predicted_Classifier_LR  \
# 22           27.0          13.0       227.5                Emerging
# 31          117.0           4.0       374.5                Emerging
# 36            2.0          18.0       189.0                Emerging
# 96           72.0           9.0       174.5                Emerging
# 115          14.0          29.0        67.0                Emerging
# 118          54.0          14.0       192.0                Emerging
# 124          89.0          19.0       288.0                Emerging
# 140          57.0           5.0       176.0                Emerging
# 195           5.0          51.0       212.0                Emerging
# 228           3.0          72.0       228.0                Emerging
# 246         163.0          15.0       271.5                Emerging
# 283          36.0          12.0       206.0                Emerging
# 300          39.0           6.0       130.5                Emerging
# 344           1.0          52.0       405.0                Emerging
#
#     Predicted_Classifier_svm Predicted_Classifier_RFC
# 22                  Emerging                 Emerging
# 31                  Emerging                 Emerging
# 36                  Emerging                 Emerging
# 96                  Emerging                 Emerging
# 115                 Emerging                 Emerging
# 118                 Emerging                 Emerging
# 124                 Emerging                 Emerging
# 140                 Emerging                 Emerging
# 195                 Emerging                 Emerging
# 228                 Emerging                 Emerging
# 246                 Emerging                 Emerging
# 283                 Emerging                 Emerging
# 300                 Emerging                 Emerging
# 344                 Emerging                 Emerging

# %%
# Choose a learning rate and create classifier
classifier = GradientBoostingClassifier(n_estimators=20,
                                        learning_rate=0.25,
                                        max_features=4,
                                        max_depth=3,
                                        random_state=42)

# Fit the model
classifier.fit(X_train, y_train)

# Make Prediction
predictions = classifier.predict(X2)
df_2024['Predicted_Classifier_GBC'] = forest_predict
df_2024.loc[df_2024['Predicted_Classifier_GBC']=='Emerging']
# Out:
#       CBSA                               Metropolitan_Area  2024_Pop_ROC  \
# 22   12420                Austin-Round Rock-Georgetown, TX          12.4
# 31   13460                                        Bend, OR          10.5
# 36   13900                                    Bismarck, ND          10.5
# 96   19780                  Des Moines-West Des Moines, IA           7.6
# 115  22020                                    Fargo, ND-MN           9.9
# 118  22220              Fayetteville-Springdale-Rogers, AR           9.7
# 124  22660                                Fort Collins, CO           9.2
# 140  24540                                     Greeley, CO          11.3
# 195  29700                                      Laredo, TX           5.9
# 228  33260                                     Midland, TX          12.3
# 246  34980  Nashville-Davidson--Murfreesboro--Franklin, TN           8.5
# 283  39580                                Raleigh-Cary, NC          10.1
# 300  41100                                  St. George, UT          10.5
# 344  45540                                The Villages, FL          17.5
#
#      2024_Unem_ROC  2024_Emp_ROC  2024_GDP_ROC  Pop_ROC_Rank  Unem_ROC_Rank  \
# 22            1.41      7.740261     23.695131           2.0          185.5
# 31            1.61      3.452002     30.132628           9.0          244.5
# 36            1.34     13.609255     22.560386           9.0          160.0
# 96            1.17      4.896860     24.355305          40.5           53.0
# 115           1.05      9.286568     20.468566          14.0           10.0
# 118           1.25      5.977000     23.579081          16.0          108.0
# 124           1.33      4.110821     22.249300          22.5          157.5
# 140           1.25      5.772005     27.541953           6.0          108.0
# 195           1.21     11.238739     18.670049          70.5           85.5
# 228           1.32     13.470572     17.938530           3.5          149.5
# 246           1.19      2.487185     23.139641          30.5           63.0
# 283           1.31      7.020570     24.100152          13.0          145.0
# 300           1.20      6.722918     27.326079           9.0           76.5
# 344           2.64     18.714580     18.666587           1.0          351.0
#
#      Emp_ROC_Rank  GDP_ROC_Rank  Rank_Total Predicted_Classifier_LR  \
# 22           27.0          13.0       227.5                Emerging
# 31          117.0           4.0       374.5                Emerging
# 36            2.0          18.0       189.0                Emerging
# 96           72.0           9.0       174.5                Emerging
# 115          14.0          29.0        67.0                Emerging
# 118          54.0          14.0       192.0                Emerging
# 124          89.0          19.0       288.0                Emerging
# 140          57.0           5.0       176.0                Emerging
# 195           5.0          51.0       212.0                Emerging
# 228           3.0          72.0       228.0                Emerging
# 246         163.0          15.0       271.5                Emerging
# 283          36.0          12.0       206.0                Emerging
# 300          39.0           6.0       130.5                Emerging
# 344           1.0          52.0       405.0                Emerging
#
#     Predicted_Classifier_svm Predicted_Classifier_RFC Predicted_Classifier_GBC
# 22                  Emerging                 Emerging                 Emerging
# 31                  Emerging                 Emerging                 Emerging
# 36                  Emerging                 Emerging                 Emerging
# 96                  Emerging                 Emerging                 Emerging
# 115                 Emerging                 Emerging                 Emerging
# 118                 Emerging                 Emerging                 Emerging
# 124                 Emerging                 Emerging                 Emerging
# 140                 Emerging                 Emerging                 Emerging
# 195                 Emerging                 Emerging                 Emerging
# 228                 Emerging                 Emerging                 Emerging
# 246                 Emerging                 Emerging                 Emerging
# 283                 Emerging                 Emerging                 Emerging
# 300                 Emerging                 Emerging                 Emerging
# 344                 Emerging                 Emerging                 Emerging
